# %%
import matplotlib.pyplot as plt
import numpy as np
#from google.colab import files

tdesu=np.linspace(0,2.55,256)
A=1
fc=7
phi=0
taudesuyo=np.linspace(0,2.55,256)
s=A*np.cos(2*np.pi*fc*tdesu+phi)
ks=[]
for time in tdesu:
  for tau in taudesuyo:
    ks.append((A*np.cos(2*np.pi*fc*(time+tau)+phi))*(A*np.cos(2*np.pi*fc*(time-tau)+phi)))
#Sa = np.fft.fft(ks)
fig_a=plt.figure(figsize=(15,5))
ax_a=plt.subplot(121)
ax_a.plot(tau,ks)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 18
#      16 fig_a=plt.figure(figsize=(15,5))
#      17 ax_a=plt.subplot(121)
# ---> 18 ax_a.plot(tau,ks)
#
# File c:\Users\Okamura\OneDrive - 近畿大学\ドキュメント\vaps\.venv\lib\site-packages\matplotlib\axes\_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1536 """
#    1537 Plot y versus x as lines and/or markers.
#    1538
#    (...)
#    1776 (``'green'``) or hex strings (``'#008000'``).
#    1777 """
#    1778 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1779 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1780 for line in lines:
#    1781     self.add_line(line)
#
# File c:\Users\Okamura\OneDrive - 近畿大学\ドキュメント\vaps\.venv\lib\site-packages\matplotlib\axes\_base.py:296, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
# ...
